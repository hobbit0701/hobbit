# %% [markdown]
# <a href="https://colab.research.google.com/github/hobbit0701/hobbit/blob/main/HW02_Web_Crawler.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # HW02 Web Crawler

# %% [markdown]
# ## 題目

# %% [markdown]
# 爬取統一發票中獎號碼

# %% [markdown]
# ## 摘要

# %% [markdown]
# 本報告透過爬取財政部網站，獲得即時統一發票中獎號碼

# %% [markdown]
# ## 方法

# %% [markdown]
# - 目標網站描述
#   - 目標網站：財政部稅務入口網
#   https://invoice.etax.nat.gov.tw/index.html
#   - 頁面結構：包含標題，公告,中獎規定,中獎號碼。
#
# - 工具與技術
#   - 使用 Python 的 `requests` 庫發送 HTTP 請求。
#   - 使用 `BeautifulSoup` 解析 HTML。
#   - 使用 `write.csv` 儲存結果

# %%
#最新一期
import requests
from bs4 import BeautifulSoup
url = 'https://invoice.etax.nat.gov.tw/index.html'
web = requests.get(url)
web.encoding='utf-8'
print(web.text)
# Out:
# <!DOCTYPE html>
# <html lang="zh-Hant-TW">
# <head>
#
#     <!-- Google Analytics -->
#     <!-- Google tag (gtag.js) -->
#     <script async src="https://www.googletagmanager.com/gtag/js?id=G-1RL7V80ELX"></script>
#     <script>
#       window.dataLayer = window.dataLayer || [];
#       function gtag(){dataLayer.push(arguments);}
#       gtag('js', new Date());
#
#       gtag('config', 'G-1RL7V80ELX');
#     </script>
#
#   <meta charset="UTF-8" />
#   <meta http-equiv="X-UA-Compatible" content="IE=edge,chrome=1" />
#   <meta name="format-detection" content="telephone=no" />
#   <meta name="viewport" content="width=device-width,initial-scale=1, user-scalable=no" />
#   <title>財政部稅務入口網</title>
#   <link rel="shortcut icon" type="image/x-icon" href="images/favicon.ico">
#   <!-- CSS_JS -->
#   <link rel="stylesheet" href="css/bootstrap.css">
#   <!-- CSS -->
#   <link rel="stylesheet" href="css/global.css">
#   <link rel="stylesheet" href="css/inner.css">
#   <!-- JS -->
# ...

# %%
from bs4 import BeautifulSoup
data=[]
soup = BeautifulSoup(web.text, "lxml")
month =soup.find("a", class_='etw-on')
print(month.text)
td = soup.select('.container-fluid')[0].select('.etw-tbiggest')

ns = td[0].getText()  # 特別獎
n1 = td[1].getText()  # 特獎

f1 = td[2].getText()[-8:]
f2 = td[3].getText()[-8:]
f3 = td[4].getText()[-8:]
print('特別獎:',ns)
print('特獎:',n1)
print('頭獎:',f1,f2,f3)
data.append(month.text)
data.append(ns)
data.append(n1)
data.append(f1)
data.append(f2)
data.append(f3)
print(data)
# Out:
# 114年03-04月中獎號碼單
# 特別獎: 64557267
# 特獎: 64808075
# 頭獎: 04322277 07903676 98883497
# ['114年03-04月中獎號碼單', '64557267', '64808075', '04322277', '07903676', '98883497']

# %%
#前一期
import requests
from bs4 import BeautifulSoup
lurl = 'https://invoice.etax.nat.gov.tw/lastNumber.html'
lweb = requests.get(lurl)
lweb.encoding='utf-8'
print(lweb.text)
# Out:
# <!DOCTYPE html>
# <html lang="zh-Hant-TW">
# <head>
#
#   <meta charset="UTF-8" />
#   <meta http-equiv="X-UA-Compatible" content="IE=edge,chrome=1" />
#   <meta name="format-detection" content="telephone=no" />
#   <meta name="viewport" content="width=device-width,initial-scale=1, user-scalable=no" />
#   <title>財政部稅務入口網</title>
#   <link rel="shortcut icon" type="image/x-icon" href="images/favicon.ico">
#   <!-- CSS_JS -->
#   <link rel="stylesheet" href="css/bootstrap.css">
#   <!-- CSS -->
#   <link rel="stylesheet" href="css/global.css">
#   <link rel="stylesheet" href="css/inner.css">
#   <!-- JS -->
#   <script type="text/javascript" src="js/jquery.min.js"></script>
#   <script type="text/javascript" src="js/bootstrap.js"></script>
#
# </head>
# <body>
# <!-- page -->
# <div class="etw-page">
#
#
#   <!-- wrapper -->
#   <div class="etw-wrapper">
#     <a href="#area_main" class="etw-pagetab" tabindex="1" title="跳到主要內容">跳到主要內容</a>
# ...

# %%
from bs4 import BeautifulSoup

data2=[]
soup = BeautifulSoup(lweb.text, "lxml")
lmonth =soup.find("a", class_='etw-on')
print(lmonth.text)
ltd = soup.find_all('p',class_='etw-tbiggest')

lns = ltd[0].getText()
ln1 = ltd[1].getText()
lf1 = ltd[2].getText()[-8:]
lf2 = ltd[3].getText()[-8:]
lf3 = ltd[4].getText()[-8:]

print('特別獎:',lns)
print('特獎:',ln1)
print('頭獎:',lf1,lf2,lf3)

data2.append(lmonth.text)
data2.append(lns)
data2.append(ln1)
data2.append(lf1)
data2.append(lf2)
data2.append(lf3)
print(data2)
# Out:
# 114年01-02月中獎號碼單
# 特別獎: 95980685
# 特獎: 37166026
# 頭獎: 78394633 26503878 39200954
# ['114年01-02月中獎號碼單', '95980685', '37166026', '78394633', '26503878', '39200954']

# %% [markdown]
# ## 結果

# %% [markdown]
# - 數據存儲方式
#   - 將數據存儲為 CSV 格式，方便後續分析。

# %%
# 展示資料程式碼
import os
import csv
with open('/content/invoice.csv','w',newline='',encoding='utf-8') as f:
    writer=csv.writer(f)
    writer.writerow(['期別', '特別獎', '特獎', '頭獎1', '頭獎2', '頭獎3'])
    writer.writerow(data)
    writer.writerow(data2)

# %% [markdown]
# ## 問題與挑戰

# %% [markdown]
# - 技術挑戰
#     網頁結構許多重複標題,需耐心尋找。
# - 技術挑戰
#     頭獎因網站顏色標示而HTML分在不同行，較難取得。

# %% [markdown]
# ## 結論

# %% [markdown]
# - 成功獲取當期和前一期的統一發票中獎號碼。
# - 未來可加上兌獎系統，輸入後3碼便可知是否中獎。

# %% [markdown]
# ## 參考文獻

# %% [markdown]
# * [財政部稅務入口網](https://invoice.etax.nat.gov.tw/index.html)
