# %% [markdown]
# <a href="https://colab.research.google.com/github/hobbit0701/hobbit/blob/main/EX03_03_%E7%A9%BA%E6%B0%A3%E5%93%81%E8%B3%AA%E6%8C%87%E6%A8%99(AQI).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
url = 'https://data.moenv.gov.tw/api/v2/aqx_p_432?api_key=9e565f9a-84dd-4e79-9097-d403cae1ea75&limit=1000&sort=ImportDate%20desc&format=CSV'
df = pd.read_csv(url)
df.head()
# Out:
#   sitename county  aqi pollutant    status  so2    co    o3  o3_8hr  pm10  \
# 0       基隆    基隆市   97     臭氧八小時        普通  NaN   NaN  79.0      69  71.0
# 1       汐止    新北市  101      懸浮微粒  對敏感族群不健康  1.9  0.22  74.0      59  76.0
# 2       萬里    新北市  109      懸浮微粒  對敏感族群不健康  1.1  0.31  81.0      73  95.0
# 3       新店    新北市  102      懸浮微粒  對敏感族群不健康  2.2  0.30  76.0      60  80.0
# 4       土城    新北市  104      懸浮微粒  對敏感族群不健康  1.8  0.28  77.0      59  85.0
#
#    ...  wind_speed  wind_direc          publishtime  co_8hr pm2.5_avg  \
# 0  ...         2.9          76  2025/04/15 15:00:00     0.2      19.2
# 1  ...         2.7           2  2025/04/15 15:00:00     0.2      19.7
# 2  ...           4          68  2025/04/15 15:00:00     0.3      19.5
# 3  ...         1.9          17  2025/04/15 15:00:00     0.3      17.8
# 4  ...         2.5         327  2025/04/15 15:00:00     0.3      21.2
#
#   pm10_avg so2_avg   longitude   latitude  siteid
# 0       71       1  121.760056  25.129167       1
# 1       76       1  121.640810  25.066240       2
# 2       94       1  121.689881  25.179667       3
# 3       78       1  121.537778  24.977222       4
# 4       82       1  121.451861  24.982528       5
#
# [5 rows x 24 columns]

# %% [markdown]
# ## 留下需要的欄位（'sitename', 'county','pollutant', 'status', 'aqi')

# %%
df = df[['sitename', 'county','pollutant', 'status', 'aqi']]
df
# Out:
#        sitename county pollutant    status  aqi
# 0            基隆    基隆市      懸浮微粒        普通   93
# 1            汐止    新北市      懸浮微粒  對敏感族群不健康  101
# 2            萬里    新北市      懸浮微粒  對敏感族群不健康  109
# 3            新店    新北市      懸浮微粒  對敏感族群不健康  102
# 4            土城    新北市      懸浮微粒  對敏感族群不健康  104
# ..          ...    ...       ...       ...  ...
# 82       屏東（琉球）    屏東縣      懸浮微粒  對敏感族群不健康  120
# 83  台中市（和平區消防隊）    臺中市      懸浮微粒  對敏感族群不健康  104
# 84       新北（樹林）    新北市      懸浮微粒  對敏感族群不健康  104
# 85       臺南（南化）    臺南市      懸浮微粒        普通   91
# 86       屏東(枋山)    屏東縣        臭氧  對敏感族群不健康  108
#
# [87 rows x 5 columns]

# %% [markdown]
# # 請找出除了空氣品質不良的測站（aqi > 100）

# %%
condition = df['aqi'] > 100
df[condition]
# Out:
#        sitename county pollutant    status  aqi
# 1            汐止    新北市      懸浮微粒  對敏感族群不健康  101
# 2            萬里    新北市      懸浮微粒  對敏感族群不健康  109
# 3            新店    新北市      懸浮微粒  對敏感族群不健康  102
# 4            土城    新北市      懸浮微粒  對敏感族群不健康  104
# 5            板橋    新北市      懸浮微粒  對敏感族群不健康  103
# ..          ...    ...       ...       ...  ...
# 81       臺南（麻豆）    臺南市      懸浮微粒  對敏感族群不健康  114
# 82       屏東（琉球）    屏東縣      懸浮微粒  對敏感族群不健康  120
# 83  台中市（和平區消防隊）    臺中市      懸浮微粒  對敏感族群不健康  104
# 84       新北（樹林）    新北市      懸浮微粒  對敏感族群不健康  104
# 86       屏東(枋山)    屏東縣        臭氧  對敏感族群不健康  108
#
# [82 rows x 5 columns]

# %% [markdown]
# # 查詢空氣污染指標物（pollutant）有那些？

# %%
df['pollutant'].unique()
# Out:
# array(['懸浮微粒', '細懸浮微粒', '臭氧八小時', '臭氧'], dtype=object)

# %% [markdown]
# # 請找出高雄市的測站資料

# %%
condition = df['county'] == '高雄市'
df[condition]
# Out:
#    sitename county  aqi pollutant    status  so2    co    o3  o3_8hr   pm10  \
# 46       美濃    高雄市   89      懸浮微粒        普通  1.2  0.17  73.0      53   85.0
# 47       橋頭    高雄市  114      懸浮微粒  對敏感族群不健康  1.7  0.20  83.0      62  138.0
# 48       仁武    高雄市  113      懸浮微粒  對敏感族群不健康  2.0  0.22  85.0      63  140.0
# 49       鳳山    高雄市  116      懸浮微粒  對敏感族群不健康  2.5  0.41  82.0      60  154.0
# 50       大寮    高雄市  108      懸浮微粒  對敏感族群不健康  5.3  0.37  81.0      63  109.0
# 51       林園    高雄市  112      懸浮微粒  對敏感族群不健康  2.5  0.23  86.0      63  109.0
# 52       楠梓    高雄市  116      懸浮微粒  對敏感族群不健康  1.5  0.22  84.0      61  151.0
# 53       左營    高雄市  114      懸浮微粒  對敏感族群不健康  1.3   NaN  81.0      63    NaN
# 54       前金    高雄市  116      懸浮微粒  對敏感族群不健康  1.7  0.23  76.0      63  144.0
# 55       前鎮    高雄市  125      懸浮微粒  對敏感族群不健康  3.7  0.26  80.0      64  189.0
# 56       小港    高雄市  113      懸浮微粒  對敏感族群不健康  3.7  0.22  79.0      61  122.0
# 69       復興    高雄市  113      懸浮微粒  對敏感族群不健康  2.5  0.22  74.0      60  127.0
# 80   高雄（湖內）    高雄市  113      懸浮微粒  對敏感族群不健康  NaN  0.21   NaN      50  126.0
#
#     ...  wind_speed  wind_direc          publishtime  co_8hr pm2.5_avg  \
# 46  ...         1.1         331  2025/04/15 15:00:00     0.1      18.2
# 47  ...         3.7         289  2025/04/15 15:00:00     0.2      30.0
# 48  ...           4         273  2025/04/15 15:00:00     0.3      26.6
# 49  ...         1.5         312  2025/04/15 15:00:00     0.4      28.9
# 50  ...         2.6         241  2025/04/15 15:00:00     0.2      23.7
# 51  ...           3         275  2025/04/15 15:00:00     0.3      30.2
# 52  ...         2.2         263  2025/04/15 15:00:00     0.2      24.8
# 53  ...         NaN         NaN  2025/04/15 15:00:00     0.2      25.6
# 54  ...         4.9         325  2025/04/15 15:00:00     0.2      28.1
# 55  ...         1.5           6  2025/04/15 15:00:00     0.3      28.2
# 56  ...         3.8         259  2025/04/15 15:00:00     0.2      28.3
# 69  ...         0.8         202  2025/04/15 15:00:00     0.3      27.7
# 80  ...         1.8         259  2025/04/15 15:00:00     0.2      24.6
#
#    pm10_avg so2_avg   longitude   latitude  siteid
# 46       65       0  120.530542  22.883583      47
# 47      106       1  120.305689  22.757506      48
# 48      105       1  120.332631  22.689056      49
# 49      111       2  120.357422  22.628126      50
# 50       93       4  120.425311  22.564136      51
# 51      102       2  120.411750  22.479500      52
# 52      112       1  120.328289  22.733667      53
# 53      106       0  120.292917  22.674861      54
# 54      112       1  120.286761  22.633903      56
# 55      131       1  120.308334  22.604451      57
# 56      103       2  120.337736  22.565833      58
# 69      104       1  120.312017  22.608711      71
# 80      103       1  120.245350  22.879856     202
#
# [13 rows x 24 columns]

# %% [markdown]
# # 計算各縣市的平均 AQI

# %%
df.groupby('county')['aqi'].mean().sort_values(ascending=False)
# Out:
# county
# 金門縣    130.000000
# 嘉義縣    119.500000
# 澎湖縣    119.000000
# 雲林縣    117.500000
# 彰化縣    117.200000
# 臺中市    116.166667
# 嘉義市    116.000000
# 臺南市    115.500000
# 苗栗縣    112.666667
# 高雄市    112.461538
# 新竹縣    111.500000
# 南投縣    111.333333
# 新竹市    110.000000
# 桃園市    109.500000
# 屏東縣    109.000000
# 新北市    106.307692
# 連江縣    106.000000
# 宜蘭縣    105.000000
# 花蓮縣    104.000000
# 臺北市    103.714286
# 基隆市     97.000000
# 臺東縣     95.500000
# Name: aqi, dtype: float64
