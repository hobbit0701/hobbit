# %% [markdown]
# <a href="https://colab.research.google.com/github/hobbit0701/hobbit/blob/main/EX04_03_%E5%AE%A2%E6%88%B6%E5%88%86%E7%BE%A4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !wget -O car_models.csv https://raw.githubusercontent.com/imchihchao/aop113b/main/materials/04-customer.csv
# Out:
# --2025-06-01 09:45:15--  https://raw.githubusercontent.com/imchihchao/aop113b/main/materials/04-customer.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2839 (2.8K) [text/plain]
# Saving to: ‘car_models.csv’
#
# car_models.csv      100%[===================>]   2.77K  --.-KB/s    in 0s
#
# 2025-06-01 09:45:15 (25.8 MB/s) - ‘car_models.csv’ saved [2839/2839]

# %%
import pandas as pd
url = 'car_models.csv'
df = pd.read_csv(url)
df.head()
# Out:
#   性別  年齡  收入（千）  消費指數（1~100）
# 0  女  74     38           81
# 1  女  51     71           91
# 2  女  30     65           10
# 3  女  88     49           17
# 4  女  55     48           70

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   性別           200 non-null    object
#  1   年齡           200 non-null    int64
#  2   收入（千）        200 non-null    int64
#  3   消費指數（1~100）  200 non-null    int64
# dtypes: int64(3), object(1)
# memory usage: 6.4+ KB

# %%
df_cor = df.drop(columns='性別').corr()
df_cor
# Out:
#                    年齡     收入（千）  消費指數（1~100）
# 年齡           1.000000  0.031519    -0.127454
# 收入（千）        0.031519  1.000000     0.031476
# 消費指數（1~100） -0.127454  0.031476     1.000000

# %% [markdown]
# **資料分割**

# %%
df['性別'].unique()
# Out:
# array(['女', '男'], dtype=object)

# %%
from sklearn.preprocessing import OrdinalEncoder
encoder = OrdinalEncoder(categories=[['女','男']])
df['性別'] = encoder.fit_transform(df[['性別']])
df
# Out:
#       性別  年齡  收入（千）  消費指數（1~100）
# 0    0.0  74     38           81
# 1    0.0  51     71           91
# 2    0.0  30     65           10
# 3    0.0  88     49           17
# 4    0.0  55     48           70
# ..   ...  ..    ...          ...
# 195  1.0  86     84           82
# 196  1.0  59     52           30
# 197  0.0  63     29           61
# 198  1.0  67     80            9
# 199  1.0  72     69           92
#
# [200 rows x 4 columns]

# %% [markdown]
# **模型訓練**

# %%
from sklearn.cluster import KMeans
kmeans = KMeans(n_clusters=3)
kmeans.fit(df)
# Out:
# KMeans(n_clusters=3)

# %%
df['cluster'] = kmeans.labels_
df
# Out:
#       性別  年齡  收入（千）  消費指數（1~100）  cluster
# 0    0.0  74     38           81        1
# 1    0.0  51     71           91        2
# 2    0.0  30     65           10        0
# 3    0.0  88     49           17        0
# 4    0.0  55     48           70        1
# ..   ...  ..    ...          ...      ...
# 195  1.0  86     84           82        2
# 196  1.0  59     52           30        0
# 197  0.0  63     29           61        1
# 198  1.0  67     80            9        0
# 199  1.0  72     69           92        2
#
# [200 rows x 5 columns]

# %% [markdown]
# **模型評估**

# %%
df.groupby('cluster').mean()
# Out:
#                性別         年齡      收入（千）  消費指數（1~100）
# cluster
# 0        0.592105  57.842105  60.381579    19.934211
# 1        0.520548  52.150685  40.479452    70.726027
# 2        0.607843  46.254902  82.764706    75.176471

# %%
from sklearn.metrics import calinski_harabasz_score
score = calinski_harabasz_score(df, kmeans.labels_)
score
# Out:
# np.float64(96.64409200841725)

# %% [markdown]
# **模型調整**

# %%
df_nocluster = df.drop(columns='cluster')
for i in range(2,16):
  kmeans = KMeans(n_clusters=i)
  kmeans.fit(df_nocluster)
  score = calinski_harabasz_score(df_nocluster, kmeans.labels_)
  print(f'n_clusters={i}, score={score}')
# Out:
# n_clusters=2, score=111.68583137120146
# n_clusters=3, score=83.3622293607023
# n_clusters=4, score=85.94215225264581
# n_clusters=5, score=80.52661833696578
# n_clusters=6, score=89.34257911353733
# n_clusters=7, score=83.34760112553234
# n_clusters=8, score=100.96529245148537
# n_clusters=9, score=97.82434553288249
# n_clusters=10, score=95.36141517287454
# n_clusters=11, score=88.75098414872676
# n_clusters=12, score=87.6634620079613
# n_clusters=13, score=83.47473271866886
# n_clusters=14, score=80.52030825180587
# n_clusters=15, score=82.71056688737086
